# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df1 = df[df['TotalCharges']!=' ']

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
# Out:
# <ipython-input-28-cffe5c08e1e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])

# %%
df1.replace('No internet service', 'No', inplace=True)
df1.replace('No phone service', 'No', inplace=True)
# Out:
# <ipython-input-29-f205fe68192d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace=True)
# <ipython-input-29-f205fe68192d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace=True)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for column in df:
    df1[column].replace({'Yes':1,'No':0},inplace=True)
# Out:
# <ipython-input-43-d77f1bbe80b5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column].replace({'Yes':1,'No':0},inplace=True)

# %%
df1['gender'].replace({'Male':1,'Female':0},inplace=True)
# Out:
# <ipython-input-44-56cf5fd99bb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df2 = pd.get_dummies(data=df1, columns = ['InternetService','Contract','PaymentMethod'])

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_0                             bool
# InternetService_DSL                           bool
# InternetService_Fiber optic                   bool
# Contract_Month-to-month                       bool
# Contract_One year                             bool
# Contract_Two year                             bool
# PaymentMethod_Bank transfer (automatic)       bool
# PaymentMethod_Credit card (automatic)         bool
# PaymentMethod_Electronic check                bool
# PaymentMethod_Mailed check                    bool
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.replace({True:1,False:0},inplace=True)

# %%
x = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train, y_train, epochs=100)

loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4909 - accuracy: 0.7732
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4288 - accuracy: 0.7975
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8048
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8048
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8066
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8064
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8091
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8105
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8132
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8123
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8139
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4018 - accuracy: 0.8133
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8123
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8174
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8169
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8162
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8158
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8201
# Epoch 19/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3936 - accuracy: 0.8194
# Epoch 20/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3921 - accuracy: 0.8197
# Epoch 21/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3911 - accuracy: 0.8192
# Epoch 22/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3902 - accuracy: 0.8180
# Epoch 23/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3888 - accuracy: 0.8196
# Epoch 24/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8172
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8203
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8213
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8210
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.8206
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8213
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8236
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8215
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8233
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8244
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8215
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3798 - accuracy: 0.8249
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8238
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8256
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8224
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8267
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8247
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8235
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8238
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8263
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8272
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8258
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8272
# Epoch 47/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3720 - accuracy: 0.8263
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8245
# Epoch 49/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3718 - accuracy: 0.8286
# Epoch 50/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3707 - accuracy: 0.8284
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3732 - accuracy: 0.8267
# Epoch 52/100
# 176/176 [==============================] - 1s 7ms/step - loss: 0.3697 - accuracy: 0.8272
# Epoch 53/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3694 - accuracy: 0.8308
# Epoch 54/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3699 - accuracy: 0.8263
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3689 - accuracy: 0.8279
# Epoch 56/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3675 - accuracy: 0.8309
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8292
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.8318
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8290
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.8288
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8276
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8293
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8292
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8270
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8322
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8293
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8295
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8302
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8334
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8324
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8309
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.8320
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3607 - accuracy: 0.8329
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8357
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8309
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3596 - accuracy: 0.8327
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3586 - accuracy: 0.8334
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8336
# Epoch 79/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8345
# Epoch 80/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3568 - accuracy: 0.8343
# Epoch 81/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3573 - accuracy: 0.8340
# Epoch 82/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3590 - accuracy: 0.8324
# Epoch 83/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3580 - accuracy: 0.8341
# Epoch 84/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3567 - accuracy: 0.8350
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8354
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8370
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8377
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8379
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3539 - accuracy: 0.8377
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8368
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3534 - accuracy: 0.8377
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8363
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3524 - accuracy: 0.8379
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.8382
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8354
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8372
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8411
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8386
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8412
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8380
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4847 - accuracy: 0.7697
# Test Accuracy: 0.7697228193283081
